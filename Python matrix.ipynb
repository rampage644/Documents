# %%
import itertools

PATH_TO_ZPYTHON2_REPO = "/home/zvm/git/zpython2"

# %% [markdown]
# According to list at https://docs.python.org/2/library/ there are 285 documented modules in python2.7 standard library.
# There also 314 modules total in default `zpython2` installation.
#
# Here the are:

# %%
modules_std = ['2to3',
 'AL',
 'BaseHTTPServer',
 'Bastion',
 'CGIHTTPServer',
 'ColorPicker',
 'ConfigParser',
 'Cookie',
 'DEVICE',
 'DocXMLRPCServer',
 'EasyDialogs',
 'FL',
 'FrameWork',
 'GL',
 'HTMLParser',
 'MacOS',
 'MimeWriter',
 'MiniAEFrame',
 'Queue',
 'SUNAUDIODEV',
 'ScrolledText',
 'SimpleHTTPServer',
 'SimpleXMLRPCServer',
 'SocketServer',
 'StringIO',
 'Tix',
 'Tkinter',
 'UserDict',
 'UserList',
 'UserString',
 '__builtin__',
 '__future__',
 '__main__',
 '_winreg',
 'abc',
 'aepack',
 'aetools',
 'aetypes',
 'aifc',
 'al',
 'anydbm',
 'argparse',
 'array',
 'ast',
 'asynchat',
 'asyncore',
 'atexit',
 'audioop',
 'autoGIL',
 'base64',
 'bdb',
 'binascii',
 'binhex',
 'bisect',
 'bsddb',
 'bz2',
 'cPickle',
 'cStringIO',
 'calendar',
 'cd',
 'cgi',
 'cgitb',
 'chunk',
 'cmath',
 'cmd',
 'code',
 'codecs',
 'codeop',
 'collections',
 'colorsys',
 'commands',
 'compileall',
 'contextlib',
 'cookielib',
 'copy',
 'copy_reg',
 'crypt',
 'csv',
 'ctypes',
 'curses',
 'curses.ascii',
 'curses.panel',
 'curses.textpad',
 'datetime',
 'dbhash',
 'dbm',
 'decimal',
 'difflib',
 'dircache',
 'dis',
 'distutils',
 'dl',
 'doctest',
 'dumbdbm',
 'dummy_thread',
 'dummy_threading',
 'email',
 'errno',
 'fcntl',
 'filecmp',
 'fileinput',
 'findertools',
 'fl',
 'flp',
 'fm',
 'fnmatch',
 'formatter',
 'fpectl',
 'fpformat',
 'fractions',
 'ftplib',
 'functools',
 'future_builtins',
 'gc',
 'gdbm',
 'gensuitemodule',
 'getopt',
 'getpass',
 'gettext',
 'gl',
 'glob',
 'grp',
 'gzip',
 'hashlib',
 'heapq',
 'hmac',
 'hotshot',
 'htmlentitydefs',
 'htmllib',
 'httplib',
 'ic',
 'imageop',
 'imaplib',
 'imgfile',
 'imghdr',
 'imp',
 'importlib',
 'imputil',
 'inspect',
 'io',
 'itertools',
 'jpeg',
 'json',
 'keyword',
 'linecache',
 'locale',
 'logging',
 'logging.config',
 'logging.handlers',
 'macostools',
 'macpath',
 'mailbox',
 'mailcap',
 'marshal',
 'math',
 'md5',
 'mhlib',
 'mimetools',
 'mimetypes',
 'mimify',
 'mmap',
 'modulefinder',
 'msilib',
 'msvcrt',
 'multifile',
 'multiprocessing',
 'mutex',
 'netrc',
 'new',
 'nis',
 'nntplib',
 'numbers',
 'operator',
 'optparse',
 'os',
 'os.path',
 'ossaudiodev',
 'parser',
 'pdb',
 'pickle',
 'pickletools',
 'pipes',
 'pkgutil',
 'platform',
 'plistlib',
 'popen2',
 'poplib',
 'posix',
 'posixfile',
 'pprint',
 'pty',
 'pwd',
 'py_compile',
 'pyclbr',
 'pydoc',
 'quopri',
 'random',
 're',
 'readline',
 'repr',
 'resource',
 'rexec',
 'rfc822',
 'rlcompleter',
 'robotparser',
 'runpy',
 'sched',
 'select',
 'sets',
 'sgmllib',
 'sha',
 'shelve',
 'shlex',
 'shutil',
 'signal',
 'site',
 'smtpd',
 'smtplib',
 'sndhdr',
 'socket',
 'spwd',
 'sqlite3',
 'ssl',
 'stat',
 'statvfs',
 'string',
 'stringprep',
 'struct',
 'subprocess',
 'sunau',
 'sunaudiodev',
 'symbol',
 'symtable',
 'sys',
 'sysconfig',
 'syslog',
 'tabnanny',
 'tarfile',
 'telnetlib',
 'tempfile',
 'termios',
 'test',
 'test.test_support',
 'textwrap',
 'thread',
 'threading',
 'time',
 'timeit',
 'token',
 'tokenize',
 'trace',
 'traceback',
 'ttk',
 'tty',
 'turtle',
 'types',
 'unicodedata',
 'unittest',
 'urllib',
 'urllib2',
 'urlparse',
 'user',
 'uu',
 'uuid',
 'warnings',
 'wave',
 'weakref',
 'webbrowser',
 'whichdb',
 'winsound',
 'wsgiref',
 'xdrlib',
 'xml.dom',
 'xml.dom.minidom',
 'xml.dom.pulldom',
 'xml.etree.ElementTree',
 'xml.parsers.expat',
 'xml.sax',
 'xml.sax.handler',
 'xml.sax.saxutils',
 'xml.sax.xmlreader',
 'xmlrpclib',
 'zipfile',
 'zipimport',
 'zlib']

# %%
total = len(modules_std); total
# Out:
# 285

# %% [markdown]
# File `status.md` contains list of unsupported modules:

# %%
from IPython.display import FileLink, FileLinks, HTML
FileLink(PATH_TO_ZPYTHON2_REPO+'/status.md')
# Out:
# /home/zvm/git/zpython2/status.md

# %%
lines = [line.strip()[2:] for line in itertools.islice(open(PATH_TO_ZPYTHON2_REPO+'/status.md').readlines(), 87, None) if line.startswith('+ ')]
uns = lines
print "%d unsupported modules" % len(uns)
# Out:
# 96 unsupported modules

# %%
lines = [line.strip()[2:] for line in itertools.islice(open(PATH_TO_ZPYTHON2_REPO+'/status.md').readlines(), 29, 82) if line.startswith('+ ')]
exp = lines
print "%d experimental modules" % len(exp)
# Out:
# 16 experimental modules

# %%
work = list(set(modules_std) - set(uns) - set(exp))
work.sort(); work
# Out:
# ['2to3',
#  'AL',
#  'Bastion',
#  'ConfigParser',
#  'Cookie',
#  'DEVICE',
#  'FL',
#  'GL',
#  'HTMLParser',
#  'MimeWriter',
#  'Queue',
#  'StringIO',
#  'UserDict',
#  'UserList',
#  'UserString',
#  '__builtin__',
#  '__future__',
#  '__main__',
#  'abc',
#  'aifc',
#  'argparse',
#  'array',
#  'ast',
#  'asynchat',
#  'atexit',
#  'audioop',
#  'base64',
#  'binascii',
#  'binhex',
#  'bisect',
#  'bz2',
#  'cPickle',
#  'cStringIO',
#  'calendar',
#  'cgi',
#  'cgitb',
#  'chunk',
#  'cmath',
#  'cmd',
#  'code',
#  'codecs',
#  'codeop',
#  'collections',
#  'colorsys',
#  'compileall',
#  'contextlib',
#  'cookielib',
#  'copy',
#  'copy_reg',
#  'crypt',
#  'csv',
#  'datetime',
#  'dbhash',
#  'decimal',
#  'difflib',
#  'dis',
#  'distutils',
#  'doctest',
#  'dumbdbm',
#  'dummy_thread',
#  'email',
#  'errno',
#  'fcntl',
#  'filecmp',
#  'fileinput',
#  'fnmatch',
#  'formatter',
#  'fpectl',
#  'fpformat',
#  'fractions',
#  'functools',
#  'future_builtins',
#  'gc',
#  'gensuitemodule',
#  'getopt',
#  'getpass',
#  'gettext',
#  'grp',
#  'gzip',
#  'hashlib',
#  'heapq',
#  'hmac',
#  'htmlentitydefs',
#  'htmllib',
#  'imageop',
#  'imghdr',
#  'imp',
#  'importlib',
#  'imputil',
#  'inspect',
#  'io',
#  'itertools',
#  'jpeg',
#  'json',
#  'keyword',
#  'linecache',
#  'locale',
#  'logging',
#  'logging.config',
#  'logging.handlers',
#  'mailcap',
#  'marshal',
#  'math',
#  'md5',
#  'mimetypes',
#  'mimify',
#  'modulefinder',
#  'multifile',
#  'mutex',
#  'netrc',
#  'new',
#  'nntplib',
#  'numbers',
#  'operator',
#  'optparse',
#  'parser',
#  'pickle',
#  'pickletools',
#  'platform',
#  'plistlib',
#  'posix',
#  'posixfile',
#  'pprint',
#  'py_compile',
#  'pyclbr',
#  'quopri',
#  'random',
#  're',
#  'repr',
#  'rexec',
#  'rfc822',
#  'rlcompleter',
#  'robotparser',
#  'runpy',
#  'sched',
#  'sets',
#  'sgmllib',
#  'sha',
#  'shelve',
#  'shlex',
#  'site',
#  'sndhdr',
#  'spwd',
#  'sqlite3',
#  'stat',
#  'statvfs',
#  'string',
#  'stringprep',
#  'struct',
#  'sunau',
#  'symbol',
#  'symtable',
#  'sys',
#  'syslog',
#  'tabnanny',
#  'tempfile',
#  'test',
#  'test.test_support',
#  'textwrap',
#  'thread',
#  'time',
#  'timeit',
#  'token',
#  'tokenize',
#  'turtle',
#  'types',
#  'unicodedata',
#  'unittest',
#  'urlparse',
#  'user',
#  'uu',
#  'warnings',
#  'wave',
#  'weakref',
#  'webbrowser',
#  'whichdb',
#  'wsgiref',
#  'xdrlib',
#  'xml.dom',
#  'xml.dom.minidom',
#  'xml.dom.pulldom',
#  'xml.etree.ElementTree',
#  'xml.parsers.expat',
#  'xml.sax',
#  'xml.sax.handler',
#  'xml.sax.saxutils',
#  'xml.sax.xmlreader',
#  'xmlrpclib',
#  'zlib']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fracs = [len(work), len(uns), len(exp)]
colors = ['g', 'r', '#FFA500']

fig, ax = plt.subplots(figsize=(6, 6))  # make the plot square
pie = ax.pie(fracs, colors=colors, explode=(0.0, 0.0, 0.0), shadow=False,
             labels=['Works', 'Unsupported', 'Experimental'])

# %%
from IPython.display import HTML, display_html
import html
import math

# %%
def table(list, columns=1):
    h = html.HTML()
    t = h.table
    rows = int(math.ceil(1.0*len(list)/columns))
    for i in range(rows):
        r = t.tr
        for j in range(columns):
            if len(list) > rows*j+i:
                r.td(list[rows*j+i][0], id=list[rows*j+i][1])
    return str(h)

# %%
l1 = [(w, 'w') for w in work]
l2 = [(e, 'e') for e in exp]
l3 = [(u, 'u') for u in uns]

# %%
display_html(table(l1+l2+l3, columns=7), raw=True)
# Out:
# <table>
# <tr><td id="w">2to3</td><td id="w">colorsys</td><td id="w">imp</td><td id="w">rexec</td><td id="w">wave</td><td id="u">aetypes</td><td id="u">pty</td></tr>
# <tr><td id="w">AL</td><td id="w">compileall</td><td id="w">importlib</td><td id="w">rfc822</td><td id="w">weakref</td><td id="u">telnetlib</td><td id="u">gdb</td></tr>
# <tr><td id="w">Bastion</td><td id="w">contextlib</td><td id="w">imputil</td><td id="w">rlcompleter</td><td id="w">webbrowser</td><td id="u">threading</td><td id="u">ntpath</td></tr>
# <tr><td id="w">ConfigParser</td><td id="w">cookielib</td><td id="w">inspect</td><td id="w">robotparser</td><td id="w">whichdb</td><td id="u">httpservers</td><td id="u">termios</td></tr>
# <tr><td id="w">Cookie</td><td id="w">copy</td><td id="w">io</td><td id="w">runpy</td><td id="w">wsgiref</td><td id="u">queue</td><td id="u">dircache</td></tr>
# <tr><td id="w">DEVICE</td><td id="w">copy_reg</td><td id="w">itertools</td><td id="w">sched</td><td id="w">xdrlib</td><td id="u">poplib</td><td id="u">glob</td></tr>
# <tr><td id="w">FL</td><td id="w">crypt</td><td id="w">jpeg</td><td id="w">sets</td><td id="w">xml.dom</td><td id="u">winreg</td><td id="u">mhlib</td></tr>
# <tr><td id="w">GL</td><td id="w">csv</td><td id="w">json</td><td id="w">sgmllib</td><td id="w">xml.dom.minidom</td><td id="u">docxmlrpc</td><td id="u">mimetools</td></tr>
# <tr><td id="w">HTMLParser</td><td id="w">datetime</td><td id="w">keyword</td><td id="w">sha</td><td id="w">xml.dom.pulldom</td><td id="u">imaplib</td><td id="u">pwd</td></tr>
# <tr><td id="w">MimeWriter</td><td id="w">dbhash</td><td id="w">linecache</td><td id="w">shelve</td><td id="w">xml.etree.ElementTree</td><td id="u">ftplib</td><td id="u">zip</td></tr>
# <tr><td id="w">Queue</td><td id="w">decimal</td><td id="w">locale</td><td id="w">shlex</td><td id="w">xml.parsers.expat</td><td id="u">urllib2</td><td id="u">zipfile</td></tr>
# <tr><td id="w">StringIO</td><td id="w">difflib</td><td id="w">logging</td><td id="w">site</td><td id="w">xml.sax</td><td id="u">urllib</td><td id="u">select</td></tr>
# <tr><td id="w">UserDict</td><td id="w">dis</td><td id="w">logging.config</td><td id="w">sndhdr</td><td id="w">xml.sax.handler</td><td id="u">httplib</td><td id="u">BaseHTTPServer</td></tr>
# <tr><td id="w">UserList</td><td id="w">distutils</td><td id="w">logging.handlers</td><td id="w">spwd</td><td id="w">xml.sax.saxutils</td><td id="u">socket</td><td id="u">CGIHTTPServer</td></tr>
# <tr><td id="w">UserString</td><td id="w">doctest</td><td id="w">mailcap</td><td id="w">sqlite3</td><td id="w">xml.sax.xmlreader</td><td id="u">smtplib</td><td id="u">ColorPicker</td></tr>
# <tr><td id="w">__builtin__</td><td id="w">dumbdbm</td><td id="w">marshal</td><td id="w">stat</td><td id="w">xmlrpclib</td><td id="u">ctypes</td><td id="u">DocXMLRPCServer</td></tr>
# <tr><td id="w">__future__</td><td id="w">dummy_thread</td><td id="w">math</td><td id="w">statvfs</td><td id="w">zlib</td><td id="u">cd</td><td id="u">EasyDialogs</td></tr>
# <tr><td id="w">__main__</td><td id="w">email</td><td id="w">md5</td><td id="w">string</td><td id="e">os</td><td id="u">readline</td><td id="u">FrameWork</td></tr>
# <tr><td id="w">abc</td><td id="w">errno</td><td id="w">mimetypes</td><td id="w">stringprep</td><td id="e">os.path</td><td id="u">cl</td><td id="u">MacOS</td></tr>
# <tr><td id="w">aifc</td><td id="w">fcntl</td><td id="w">mimify</td><td id="w">struct</td><td id="e">dummy_threading</td><td id="u">sv</td><td id="u">MiniAEFrame</td></tr>
# <tr><td id="w">argparse</td><td id="w">filecmp</td><td id="w">modulefinder</td><td id="w">sunau</td><td id="e">mmap</td><td id="u">al</td><td id="u">SUNAUDIODEV</td></tr>
# <tr><td id="w">array</td><td id="w">fileinput</td><td id="w">multifile</td><td id="w">symbol</td><td id="e">hotshot</td><td id="u">bsddb</td><td id="u">ScrolledText</td></tr>
# <tr><td id="w">ast</td><td id="w">fnmatch</td><td id="w">mutex</td><td id="w">symtable</td><td id="e">tarfile</td><td id="u">gl</td><td id="u">SimpleHTTPServer</td></tr>
# <tr><td id="w">asynchat</td><td id="w">formatter</td><td id="w">netrc</td><td id="w">sys</td><td id="e">uuid</td><td id="u">ssl</td><td id="u">SimpleXMLRPCServer</td></tr>
# <tr><td id="w">atexit</td><td id="w">fpectl</td><td id="w">new</td><td id="w">syslog</td><td id="e">import</td><td id="u">sunaudiodev</td><td id="u">SocketServer</td></tr>
# <tr><td id="w">audioop</td><td id="w">fpformat</td><td id="w">nntplib</td><td id="w">tabnanny</td><td id="e">shutil</td><td id="u">winsound</td><td id="u">Tix</td></tr>
# <tr><td id="w">base64</td><td id="w">fractions</td><td id="w">numbers</td><td id="w">tempfile</td><td id="e">trace</td><td id="u">multiprocessing</td><td id="u">_winreg</td></tr>
# <tr><td id="w">binascii</td><td id="w">functools</td><td id="w">operator</td><td id="w">test</td><td id="e">hash</td><td id="u">nis</td><td id="u">autoGIL</td></tr>
# <tr><td id="w">binhex</td><td id="w">future_builtins</td><td id="w">optparse</td><td id="w">test.test_support</td><td id="e">warning</td><td id="u">macos</td><td id="u">bdb</td></tr>
# <tr><td id="w">bisect</td><td id="w">gc</td><td id="w">parser</td><td id="w">textwrap</td><td id="e">sysconfig</td><td id="u">dbm</td><td id="u">curses.ascii</td></tr>
# <tr><td id="w">bz2</td><td id="w">gensuitemodule</td><td id="w">pickle</td><td id="w">thread</td><td id="e">pkgutil</td><td id="u">gdbm</td><td id="u">curses.panel</td></tr>
# <tr><td id="w">cPickle</td><td id="w">getopt</td><td id="w">pickletools</td><td id="w">time</td><td id="e">pydoc</td><td id="u">anydbm</td><td id="u">curses.textpad</td></tr>
# <tr><td id="w">cStringIO</td><td id="w">getpass</td><td id="w">platform</td><td id="w">timeit</td><td id="e">traceback</td><td id="u">imgfile</td><td id="u">fl</td></tr>
# <tr><td id="w">calendar</td><td id="w">gettext</td><td id="w">plistlib</td><td id="w">token</td><td id="u">subprocess</td><td id="u">msilib</td><td id="u">flp</td></tr>
# <tr><td id="w">cgi</td><td id="w">grp</td><td id="w">posix</td><td id="w">tokenize</td><td id="u">popen</td><td id="u">ossaudiodev</td><td id="u">fm</td></tr>
# <tr><td id="w">cgitb</td><td id="w">gzip</td><td id="w">posixfile</td><td id="w">turtle</td><td id="u">popen2</td><td id="u">linuxaudiodev</td><td id="u">ic</td></tr>
# <tr><td id="w">chunk</td><td id="w">hashlib</td><td id="w">pprint</td><td id="w">types</td><td id="u">curses</td><td id="u">dl</td><td id="u">findertools</td></tr>
# <tr><td id="w">cmath</td><td id="w">heapq</td><td id="w">py_compile</td><td id="w">unicodedata</td><td id="u">signal</td><td id="u">commands</td><td id="u">gensuitmodule</td></tr>
# <tr><td id="w">cmd</td><td id="w">hmac</td><td id="w">pyclbr</td><td id="w">unittest</td><td id="u">pipes</td><td id="u">asyncore</td><td id="u">macostools</td></tr>
# <tr><td id="w">code</td><td id="w">htmlentitydefs</td><td id="w">quopri</td><td id="w">urlparse</td><td id="u">Tkinter</td><td id="u">zipimport</td><td id="u">msvcrt</td></tr>
# <tr><td id="w">codecs</td><td id="w">htmllib</td><td id="w">random</td><td id="w">user</td><td id="u">mailbox</td><td id="u">pdb</td><td id="u">smtpd</td></tr>
# <tr><td id="w">codeop</td><td id="w">imageop</td><td id="w">re</td><td id="w">uu</td><td id="u">aetools</td><td id="u">macpath</td><td id="u">ttk</td></tr>
# <tr><td id="w">collections</td><td id="w">imghdr</td><td id="w">repr</td><td id="w">warnings</td><td id="u">aepack</td><td id="u">resource</td><td id="u">tty</td></tr>
# </table>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("style.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# td {
#   text-align: right;
#   padding-left: 1em;
# }
#
# #w {
#   background-color: green;
# }
# #u {
#   background-color: red;
# }
# #e {
#   background-color: orange;
# }
# table {
#   width:100%;
# }
#
# div.warn {
#   background-color: #fcf2f2;
#   border-color: #dFb5b4;
#   border-left: 5px solid #dfb5b4;
#   padding: 0.5em;
# }
#
# </style>
